# %%
import argparse
import os
import random

import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
import pydicom
from pydicom.dataset import Dataset
from pydicom.sequence import Sequence
from skimage import measure

# %%
# Load RTSTRUCT
ds = pydicom.dcmread("tumor.dcm", stop_before_pixels=True)

# Fix meta info
ds.fix_meta_info()

ds.SpecificCharacterSet = "ISO_IR 192"
ds.InstanceCreationDate = ds.StudyDate
ds.InstanceCreationTime = ds.StudyTime
ds.Manufacturer = "manuf"
ds.ReferringPhysicianName = "refPhys"
ds.StudyDescription = "studDesc"
ds.ManufacturerModelName = "manufModName"
ds.PatientName = ""
ds.DeviceSerialNumber = "devSerNum"
ds.SoftwareVersions = "softVer"
ds.StudyID = "studId"
ds.SeriesNumber = "1234"
del(ds.ImageType)
del(ds.ContentDate)
del(ds.AcquisitionDateTime)
del(ds.ContentTime)
del(ds.MRAcquisitionType)
del(ds.SliceThickness)
del(ds.RepetitionTime)
del(ds.EchoTime)
del(ds.MagneticFieldStrength)
del(ds.EchoTrainLength)
del(ds.PatientPosition)
del(ds.ImagePositionPatient)
del(ds.ImageOrientationPatient)
del(ds.FrameOfReferenceUID)
del(ds.PositionReferenceIndicator)
del(ds.SliceLocation)
del(ds.SamplesPerPixel)
del(ds.PhotometricInterpretation)
del(ds.NumberOfFrames)
del(ds.Rows)
del(ds.Columns)
del(ds.PixelSpacing)
del(ds.BitsAllocated)
del(ds.BitsStored)
del(ds.HighBit)
del(ds.PixelRepresentation)
del(ds.SmallestImagePixelValue)
del(ds.LargestImagePixelValue)
del(ds.SmallestPixelValueInSeries)
del(ds.LargestPixelValueInSeries)
del(ds.BurnedInAnnotation)
del(ds.WindowCenter)
del(ds.WindowWidth)
del(ds.LossyImageCompression)

ds.ReferencedFrameOfReferenceSequence[0].RTReferencedStudySequence[0].ReferencedSOPInstanceUID = ds.StudyInstanceUID
ds.StructureSetROISequence[0].ROIGenerationAlgorithm = ""

ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 210
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.20645213724194321925313055550110232499
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.9590.100.1.3.100.9.4
# (0002, 0013) Implementation Version Name         SH: 'MATLAB IPT 9.4'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20200414'
# (0008, 0013) Instance Creation Time              TM: '181713'
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# ...

# %%
ds.SeriesDescription = "test_test_test"

# %%
ds.save_as('test_test_test.dcm')

# %%
[x.ReferencedSOPInstanceUID for x in ds.ReferencedFrameOfReferenceSequence[0].RTReferencedStudySequence[0].RTReferencedSeriesSequence[0].ContourImageSequence]
# Out:
# ['1.3.6.1.4.1.9590.100.1.2.20645213724194321925313055550110232499',
#  '1.3.6.1.4.1.9590.100.1.2.154524831903613813024776757764201833660',
#  '1.3.6.1.4.1.9590.100.1.2.7489750416680609424579272802871671905',
#  '1.3.6.1.4.1.9590.100.1.2.293343736626151090831100365630466374951',
#  '1.3.6.1.4.1.9590.100.1.2.382327122431137099128176236782718266192',
#  '1.3.6.1.4.1.9590.100.1.2.253529250414113343427361704623324804943',
#  '1.3.6.1.4.1.9590.100.1.2.394714236338258951823027515020368958616',
#  '1.3.6.1.4.1.9590.100.1.2.317664159837577954826534456390338231062',
#  '1.3.6.1.4.1.9590.100.1.2.58054090336521160024439034442554956848',
#  '1.3.6.1.4.1.9590.100.1.2.231258600206182464027430969804144108370',
#  '1.3.6.1.4.1.9590.100.1.2.147951765018939060326226945600507289689',
#  '1.3.6.1.4.1.9590.100.1.2.396732807104976688730312045013975164793',
#  '1.3.6.1.4.1.9590.100.1.2.35613205002611001127043102823113839910',
#  '1.3.6.1.4.1.9590.100.1.2.213819430400480575431604323901686310901',
# ...
